# %% [markdown]
# # Introduction to baseball #
#
# If you're not familiar with baseball, here's a few video that explains the basics of the game.
#
# <a href="https://www.youtube.com/watch?v=I8VGW0C_GO4" target="_blank">Baseball explained in 5 minutes</a>
#
# ## Game overview ##
# The game consists of 9 innings, usually
# Both teams get to bat each inning
# A team's at-bat is over when they get 3 outs in an inning.
# In Major League Baseball, there are two leagues - the National League and the American League, and they have slightly different rules.
#
# ## Defensive details ##
# There are 25 players on each team. There are 9 defensive positions:
# 1. Pitcher
# 2. Catcher
# 3. First base
# 4. Second base
# 5. Third base
# 6. Shortstop
# 7. Left field
# 8. Center field
# 9. Right field
#
# A team typically uses multiple pitchers in a game. There is a pitcher who starts the game, called the starting pitcher, and there are relief pitchers, pitchers who replace the starting pitcher late in the game. The other players, called position players, typically play the whole game, but not always. They can be replaced at any time by a bench player, an extra player who didn't start the game.
# ### Pitching ###
# The pitcher throws the ball to home plate for the batter to hit. If the pitch crosses home plate and is between the batters knees and chest, it is in the strikezone and should be called a strike. If the pitch is outside this zone, the pitch is a ball, and hopefully the umpire calls it a ball. If the batter gets three strikes, either by pitches in the zone that he doesn't swing at, or pitches anywhere that he swings at and misses, then he's out. If the batter gets four balls, he gets a walk and can go to first base.
#
# ## Offensive details ##
# All players who play defensive get a chance to bat in the National League. For the American League, pitchers don't bat. Each team has a batting order, which is the order in which batters are expected to come to bat. When a player comes up to bat, his objective is to get on base. The objective of the defense is to get the batter out.
#
# A batter typically gets on base through:
# * A Hit -single, double, triple, homerun
# * A Walk
# * Getting hit by the pitch
# * Defensive error
# * Fielder's choice
#
# # Common baseball statistics #
# Do statistics help us predict the future? Here's what someone at FanGraphs had to say: <a href="https://library.fangraphs.com/the-beginners-guide-to-understanding-descriptive-and-predictive-stats/" target="_blank">Descriptive vs. predictive statistics</a>.
#
# ## Offensive statistics ##
# ### Counting statistics ###
# Count the number of times an event occurred. Here are some of the most common events that we count and include in other more complicated statistics.
# * **At-bat (AB)** - a plate-appearance that ends with an out, fielder's choice, hit, or error. Doesn't include walks, sacrifice, hit-by-pitch.
# * **Hit (H)** - batter reaches base by contacting the ball and there isn't an error or fielder's choice. Hits include singles (1B), doubles (2B), triples (3B), or homeruns (H).
# * **Plate appearances (PA)** - number of times a batter came to the plate and produced an outcome. If there is a caught stealing during a plate appearance and it ends the inning, the batter doesn't get credit for the plate appearance.
# * **Runs batted in (RBI)** - a plate-appearance results in a run scoring where there wasn't an error and the batter didn't ground into a double play.
# * **Stolen bases (SB)** - base runner moves from one base to the next while another player is up to bat and the ball has not been put into play by the batter. The number of times that a player is caught stealing is also counted.
# * **Strike-out (K)** - batter swings at 3 pitches and doesn't make contact, or hits the ball foul on the first 2 strikes.
# * **Walk (BB)** - batter goes to first base after pitcher throws 4 pitches out of the strike zone and the batter doesn't swing.
#
# ### Descriptive statistics ###
# Provide a summary of the data.
# * **Batting average (BA)** - hits / AB. Notice that anything not included in AB is also not considered in BA. League BA is typically around 0.267. Even back in 1880 people made fun of BA as a statistic.
# * **On-base percentage (OBP)** - captures how frequently a player gets on base by a hit, walk, or getting hit by the pitch.
#
# $$OBP=\frac{H+BB+HBP}{PA}$$
#
# * **Slugging percentage (SLG)** - captures the number of bases a player records per AB.
#
# $$SLG=\frac{1B + 2Bx2 + 3Bx3 + HRx4}{AB}$$.
#
# * **On-base plus slugging (OPS)** - combines power and on-base statistics.
#
# $$OPS = OBP + SLG$$
#
# * **Batting average on balls in play (BABIP)** - measures how often a ball put in play results in a hit. The league average is about 0.300. A ball “in play” includes everything that isn't a strikeout, walk, hit batter, catcher’s interference, sacrifice bunt, or home run. This is a controversial statistic because for a long time, people thought pitchers had more control over babip than they actually do. <a href="https://library.fangraphs.com/pitching/babip/" target="_blank">BABIP Explained by FanGraphs</a> The babip formula is:
# $$BABIP=\frac{H-HR}{AB-K-HR+SF}$$
#
# * **Weighted on-base average (WOBA)** - applies linear weights to offensive events to reflect observed contribution to run scoring. Linear weights change slightly every year to consider the run-scoring environment that year. Results are scaled to be similar to OBP. For 2018, the woba formula was:
#
# $$wOBA=\frac{0.69*NIBB + 0.72*HBP + 0.88*1B + 1.247*2B + 1.578*3B +
# 2.031*HR}{AB + NIBB + SF + HBP}$$
#
# * **Wins above replacement (WAR)** - how many wins does a player contribute above what a replacement player would contribute. Replacement is a league-minimum player, or minor league replacement. This calculation includes both offensive and defensive contributions. We'll talk more about it at a later time.
#
# ## Defensive statistics ##
# ### Pitching ###
# #### Counting statistics ####
# * **Wins (W)** - number of games where pitcher left the game with the lead, team won the game, and pitcher completed at least 5 innings.
# * **Losses (L)**- number of games where pitcher left game and team was losing and team didn't at least even up the score. There is no minimum number of innings that pitcher needs to complete to earn a loss.
# * **Strikeouts** - how many batters did pitcher strikeout so far in a season.
# * **W, H, R, etc** - how many walks, hits, runs, and so on has the pitcher given up this season.
# * **Innings pitched (IP)** - each out recorded is 1/3 of an inning. Three outs recorded is one inning pitched.
#
# #### Descriptive statistics ####
# * **Earned Run Average (ERA)** - number of earned runs a pitcher allows per nine innings. An earned run is a run that didn't result from a fielding error. The formula is:
#
# $$ERA = \frac{9 * earned runs}{innings pitched}$$
# * **Fielding independent pitching (FIP)** - captures a pitcher's performance independent of actions involving the defense. Defense varies team to team, season to season, day to day, park to park. Only includes outcomes that are "entirely" the pitcher's fault, by some definition of fault. <a href="https://library.fangraphs.com/pitching/fip/" target="_blank">FIP Explained by FanGraphs</a>
#
# $$FIP=\frac{13*HR+3*(HBP+BB)-2*K}{IP}+c$$, $$c\approx3.2$$
#
# ### Fielding ###
# * **Errors (E)** - fielder doesn't generate an out on a play that an average fielder would make. For example, ground ball to the shortstop that goes between his legs, or an overthrow to first base.
# * **Double plays (DP)** - defense generates two outs on a play. For example, ground ball to shortstop that goes to second and then first that gets runners out at second and first. Can be misleading as statistic of defensive quality because having a lot of DP means that a team lets a lot of runners get on base.
# * **Defensive efficiency ratio (DER)** - measures how effective a defense is at recording an out on a ball put in play.
# $$DER=1-\frac{(H + ROE - HR)}{(PA - BB - SO - HBP - HR)}$$

# %% [markdown]
# # In-class assignment and discussion #
# Working with people at your table, or alone, respond to the following questions. Your answers are due before class on Monday.
# 1. Why is SLG an imperfect measure of how a hit contributes to run production?

# %% [markdown]
# 2. What factors contribute to a player's RBI total that have nothing to do with the player's ability?

# %% [markdown]
# 3. Player A and Player B are both shortstops being considered for an award for defensive ability. Player A has 1 error in 200 chances and Player B has 3 errors for the same number of chances. Can we say definitively that Player A is better than Player B?

# %% [markdown]
# 4. How can a team's defensive ability affect a pitcher's ERA?

# %% [markdown]
# 5. What will become of DJ Lemahieu now that he's left the Rockies. Here's what a guy from MLB.com had to say:
# <a href="https://www.mlb.com/news/dj-lemahieu-leaves-coors-field-for-the-bronx/c-302622392"  target="_blank">DJ we wish you well</a>. Will he be successful in NY? Referencing at least one of the statistics that we covered today, predict whether DJ will find success once he leaves Coors Field. You don't need to do the calculations, just present your thoughts.

# %% [markdown]
# ## Before class on Wednesday, install pybaseball ##
# In Wednesday's class, I will be discussing the basics of PANDAS and the pybaseball Python package. If you want to follow along, you'll need to have pybaseball installed.
#
# Open a terminal and type the following commands to pull the latest pybaseball
#
# * git clone https://github.com/jldbc/pybaseball
# * cd pybaseball
# * python setup.py install --user
#
# To test that pybaseball installed correctly, run the following. If you get back data, pybaseball is working.

# %%
from pybaseball import statcast
data = statcast(start_dt='2015-06-24', end_dt='2015-06-27')
data.head(100)
# Out:
#     index pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0     447         FF 2015-06-27           94.5        -1.4380         6.0761
# 1     462         CH 2015-06-27           81.9        -1.3544         5.9262
# 2     466         FF 2015-06-27           95.0        -1.4401         6.2204
# 3     480         FT 2015-06-27           91.9        -0.4390         6.6065
# 4     491         FT 2015-06-27           92.3        -0.6665         6.5995
# 5     501         SL 2015-06-27           88.2        -1.3684         6.7131
# 6     511         FF 2015-06-27           91.1        -1.1067         6.6683
# 7     522         FT 2015-06-27           90.6        -1.0029         6.7039
# 8     535         SI 2015-06-27           97.0         3.9718         5.2900
# 9     543         SI 2015-06-27           96.7         4.0256         5.4115
# 10    559         SI 2015-06-27           96.4         4.0287         5.3507
# 11    567         SI 2015-06-27           96.5         4.0781         5.3230
# 12    575         SI 2015-06-27           95.6         4.0896         5.4565
# 13    588         SI 2015-06-27           95.2         4.1005         5.2400
# 14    603         SI 2015-06-27           94.7         4.1062         5.2428
# 15    615         SI 2015-06-27           90.8        -1.2820         5.3777
# 16    621         SL 2015-06-27           84.6        -2.0691         4.1509
# 17    628         SI 2015-06-27           91.7        -1.2160         5.1977
# 18    645         SI 2015-06-27           90.5        -1.2612         5.4045
# 19    656         SI 2015-06-27           87.6        -1.7992         4.5849
# 20    668         SI 2015-06-27           90.5        -1.3023         5.2829
# 21    680         SI 2015-06-27           90.4        -1.2296         5.3070
# 22    693         CH 2015-06-27           84.4        -1.5467         5.2537
# 23    703         SI 2015-06-27           91.6        -1.3826         5.2919
# 24    713         SI 2015-06-27           91.3        -1.3412         5.2341
# 25    725         SI 2015-06-27           90.7        -1.2796         5.3492
# 26    735         SI 2015-06-27           90.5        -1.5153         5.3149
# 27    747         FT 2015-06-27           93.4        -0.6298         6.5322
# 28    761         FF 2015-06-27           93.1        -0.4138         6.5623
# 29    774         FF 2015-06-27           92.6        -0.8375         6.5827
# ..    ...        ...        ...            ...            ...            ...
# 70   1259         SL 2015-06-27           80.2         1.1717         6.0594
# 71   1274         FF 2015-06-27           93.7         0.7833         6.1201
# 72   1282         SL 2015-06-27           80.3         1.3129         6.0284
# 73   1303         SL 2015-06-27           79.5         1.0524         6.0699
# 74   1307         CH 2015-06-27           80.8         0.7561         6.3416
# 75   1329         FF 2015-06-27           90.6         0.6696         6.3014
# 76   1331         FF 2015-06-27           92.3         0.9807         6.2597
# 77   1346         FF 2015-06-27           89.7         1.0565         6.2644
# 78   1362         SL 2015-06-27           78.3         1.2271         6.1983
# 79   1368         FF 2015-06-27           93.2        -0.5747         6.5143
# 80   1384         FT 2015-06-27           93.3        -0.6841         6.4355
# 81   1390         FF 2015-06-27           91.8        -0.7681         6.6500
# 82   1404         SL 2015-06-27           88.2        -1.0316         6.4646
# 83   1419         FT 2015-06-27           92.0        -0.9671         6.5634
# 84   1430         FF 2015-06-27           92.1        -0.8304         6.5424
# 85   1440         FF 2015-06-27           90.5        -0.9959         6.6625
# 86   1450         FT 2015-06-27           91.2        -0.9133         6.6646
# 87   1464         FF 2015-06-27           91.0        -0.9283         6.6946
# 88   1474         SL 2015-06-27           88.1        -1.1334         6.6677
# 89   1492         FF 2015-06-27           91.1        -0.7312         6.6023
# 90   1500         SL 2015-06-27           79.6         0.9129         6.0262
# 91   1520         FF 2015-06-27           87.9         0.8026         6.3410
# 92   1531         FF 2015-06-27           90.0         0.7111         6.2617
# 93   1542         SL 2015-06-27           80.9         0.9493         5.9630
# 94   1552         FF 2015-06-27           90.8         0.7073         6.2465
# 95   1565         FF 2015-06-27           88.3         0.3022         6.5204
# 96   1573         FF 2015-06-27           91.6         0.7308         6.2530
# 97   1587         FF 2015-06-27           90.1         0.8464         6.2880
# 98   1597         CH 2015-06-27           78.0         0.7817         6.4003
# 99   1616         FF 2015-06-27           91.5         0.8128         6.4309
#
#         player_name    batter   pitcher                     events  \
# 0    Shawn Tolleson  430832.0  474521.0  grounded_into_double_play
# 1    Shawn Tolleson  430832.0  474521.0                        NaN
# 2    Shawn Tolleson  430832.0  474521.0                        NaN
# 3   Yovani Gallardo  518626.0  451596.0                     single
# 4   Yovani Gallardo  518626.0  451596.0                        NaN
# 5   Yovani Gallardo  408314.0  451596.0                  field_out
# 6   Yovani Gallardo  408314.0  451596.0                        NaN
# 7   Yovani Gallardo  408314.0  451596.0                        NaN
# 8        Aaron Loup  547982.0  571901.0                  strikeout
# 9        Aaron Loup  547982.0  571901.0                        NaN
# 10       Aaron Loup  547982.0  571901.0                        NaN
# 11       Aaron Loup  425783.0  571901.0                  strikeout
# 12       Aaron Loup  425783.0  571901.0                        NaN
# 13       Aaron Loup  425783.0  571901.0                        NaN
# 14       Aaron Loup  425783.0  571901.0                        NaN
# 15     Todd Redmond  455139.0  445170.0                  strikeout
# 16     Todd Redmond  455139.0  445170.0                        NaN
# 17     Todd Redmond  455139.0  445170.0                        NaN
# 18     Todd Redmond  455139.0  445170.0                        NaN
# 19     Todd Redmond  455139.0  445170.0                        NaN
# 20     Todd Redmond  455139.0  445170.0                        NaN
# 21     Todd Redmond  455139.0  445170.0                        NaN
# 22     Todd Redmond  596059.0  445170.0                     single
# 23     Todd Redmond  596059.0  445170.0                        NaN
# 24     Todd Redmond  596059.0  445170.0                        NaN
# 25     Todd Redmond  596059.0  445170.0                        NaN
# 26     Todd Redmond  596059.0  445170.0                        NaN
# 27  Yovani Gallardo  581527.0  451596.0                  field_out
# 28  Yovani Gallardo  607680.0  451596.0                     single
# 29  Yovani Gallardo  607680.0  451596.0                        NaN
# ..              ...       ...       ...                        ...
# 70     Matthew Boyd  425783.0  571510.0                  strikeout
# 71     Matthew Boyd  425783.0  571510.0                        NaN
# 72     Matthew Boyd  425783.0  571510.0                        NaN
# 73     Matthew Boyd  425783.0  571510.0                        NaN
# 74     Matthew Boyd  455139.0  571510.0                  field_out
# 75     Matthew Boyd  455139.0  571510.0                        NaN
# 76     Matthew Boyd  455139.0  571510.0                        NaN
# 77     Matthew Boyd  596059.0  571510.0                   home_run
# 78     Matthew Boyd  596059.0  571510.0                        NaN
# 79  Yovani Gallardo  518626.0  451596.0                  strikeout
# 80  Yovani Gallardo  518626.0  451596.0                        NaN
# 81  Yovani Gallardo  518626.0  451596.0                        NaN
# 82  Yovani Gallardo  518626.0  451596.0                        NaN
# 83  Yovani Gallardo  518626.0  451596.0                        NaN
# 84  Yovani Gallardo  518626.0  451596.0                        NaN
# 85  Yovani Gallardo  408314.0  451596.0                  field_out
# 86  Yovani Gallardo  408314.0  451596.0                        NaN
# 87  Yovani Gallardo  408314.0  451596.0                        NaN
# 88  Yovani Gallardo  581527.0  451596.0                  field_out
# 89  Yovani Gallardo  581527.0  451596.0                        NaN
# 90     Matthew Boyd  608336.0  571510.0                  field_out
# 91     Matthew Boyd  608336.0  571510.0                        NaN
# 92     Matthew Boyd  608336.0  571510.0                        NaN
# 93     Matthew Boyd  608336.0  571510.0                        NaN
# 94     Matthew Boyd  462101.0  571510.0                  field_out
# 95     Matthew Boyd  519048.0  571510.0                  force_out
# 96     Matthew Boyd  519048.0  571510.0                        NaN
# 97     Matthew Boyd  134181.0  571510.0                     single
# 98     Matthew Boyd  134181.0  571510.0                        NaN
# 99     Matthew Boyd  134181.0  571510.0                        NaN
#
#             ...          home_score  away_score  bat_score  fld_score  \
# 0           ...                 0.0         4.0        0.0        4.0
# 1           ...                 0.0         4.0        0.0        4.0
# 2           ...                 0.0         4.0        0.0        4.0
# 3           ...                 0.0         4.0        0.0        4.0
# 4           ...                 0.0         4.0        0.0        4.0
# 5           ...                 0.0         4.0        0.0        4.0
# 6           ...                 0.0         4.0        0.0        4.0
# 7           ...                 0.0         4.0        0.0        4.0
# 8           ...                 0.0         4.0        4.0        0.0
# 9           ...                 0.0         4.0        4.0        0.0
# 10          ...                 0.0         4.0        4.0        0.0
# 11          ...                 0.0         4.0        4.0        0.0
# 12          ...                 0.0         4.0        4.0        0.0
# 13          ...                 0.0         4.0        4.0        0.0
# 14          ...                 0.0         4.0        4.0        0.0
# 15          ...                 0.0         4.0        4.0        0.0
# 16          ...                 0.0         4.0        4.0        0.0
# 17          ...                 0.0         4.0        4.0        0.0
# 18          ...                 0.0         4.0        4.0        0.0
# 19          ...                 0.0         4.0        4.0        0.0
# 20          ...                 0.0         4.0        4.0        0.0
# 21          ...                 0.0         4.0        4.0        0.0
# 22          ...                 0.0         4.0        4.0        0.0
# 23          ...                 0.0         4.0        4.0        0.0
# 24          ...                 0.0         4.0        4.0        0.0
# 25          ...                 0.0         4.0        4.0        0.0
# 26          ...                 0.0         4.0        4.0        0.0
# 27          ...                 0.0         4.0        0.0        4.0
# 28          ...                 0.0         4.0        0.0        4.0
# 29          ...                 0.0         4.0        0.0        4.0
# ..          ...                 ...         ...        ...        ...
# 70          ...                 0.0         4.0        4.0        0.0
# 71          ...                 0.0         4.0        4.0        0.0
# 72          ...                 0.0         4.0        4.0        0.0
# 73          ...                 0.0         4.0        4.0        0.0
# 74          ...                 0.0         4.0        4.0        0.0
# 75          ...                 0.0         4.0        4.0        0.0
# 76          ...                 0.0         4.0        4.0        0.0
# 77          ...                 0.0         3.0        3.0        0.0
# 78          ...                 0.0         3.0        3.0        0.0
# 79          ...                 0.0         3.0        0.0        3.0
# 80          ...                 0.0         3.0        0.0        3.0
# 81          ...                 0.0         3.0        0.0        3.0
# 82          ...                 0.0         3.0        0.0        3.0
# 83          ...                 0.0         3.0        0.0        3.0
# 84          ...                 0.0         3.0        0.0        3.0
# 85          ...                 0.0         3.0        0.0        3.0
# 86          ...                 0.0         3.0        0.0        3.0
# 87          ...                 0.0         3.0        0.0        3.0
# 88          ...                 0.0         3.0        0.0        3.0
# 89          ...                 0.0         3.0        0.0        3.0
# 90          ...                 0.0         3.0        3.0        0.0
# 91          ...                 0.0         3.0        3.0        0.0
# 92          ...                 0.0         3.0        3.0        0.0
# 93          ...                 0.0         3.0        3.0        0.0
# 94          ...                 0.0         3.0        3.0        0.0
# 95          ...                 0.0         3.0        3.0        0.0
# 96          ...                 0.0         3.0        3.0        0.0
# 97          ...                 0.0         3.0        3.0        0.0
# 98          ...                 0.0         3.0        3.0        0.0
# 99          ...                 0.0         3.0        3.0        0.0
#
#     post_away_score  post_home_score post_bat_score post_fld_score  \
# 0               4.0              0.0            0.0            4.0
# 1               4.0              0.0            0.0            4.0
# 2               4.0              0.0            0.0            4.0
# 3               4.0              0.0            0.0            4.0
# 4               4.0              0.0            0.0            4.0
# 5               4.0              0.0            0.0            4.0
# 6               4.0              0.0            0.0            4.0
# 7               4.0              0.0            0.0            4.0
# 8               4.0              0.0            4.0            0.0
# 9               4.0              0.0            4.0            0.0
# 10              4.0              0.0            4.0            0.0
# 11              4.0              0.0            4.0            0.0
# 12              4.0              0.0            4.0            0.0
# 13              4.0              0.0            4.0            0.0
# 14              4.0              0.0            4.0            0.0
# 15              4.0              0.0            4.0            0.0
# 16              4.0              0.0            4.0            0.0
# 17              4.0              0.0            4.0            0.0
# 18              4.0              0.0            4.0            0.0
# 19              4.0              0.0            4.0            0.0
# 20              4.0              0.0            4.0            0.0
# 21              4.0              0.0            4.0            0.0
# 22              4.0              0.0            4.0            0.0
# 23              4.0              0.0            4.0            0.0
# 24              4.0              0.0            4.0            0.0
# 25              4.0              0.0            4.0            0.0
# 26              4.0              0.0            4.0            0.0
# 27              4.0              0.0            0.0            4.0
# 28              4.0              0.0            0.0            4.0
# 29              4.0              0.0            0.0            4.0
# ..              ...              ...            ...            ...
# 70              4.0              0.0            4.0            0.0
# 71              4.0              0.0            4.0            0.0
# 72              4.0              0.0            4.0            0.0
# 73              4.0              0.0            4.0            0.0
# 74              4.0              0.0            4.0            0.0
# 75              4.0              0.0            4.0            0.0
# 76              4.0              0.0            4.0            0.0
# 77              3.0              0.0            3.0            0.0
# 78              3.0              0.0            3.0            0.0
# 79              3.0              0.0            0.0            3.0
# 80              3.0              0.0            0.0            3.0
# 81              3.0              0.0            0.0            3.0
# 82              3.0              0.0            0.0            3.0
# 83              3.0              0.0            0.0            3.0
# 84              3.0              0.0            0.0            3.0
# 85              3.0              0.0            0.0            3.0
# 86              3.0              0.0            0.0            3.0
# 87              3.0              0.0            0.0            3.0
# 88              3.0              0.0            0.0            3.0
# 89              3.0              0.0            0.0            3.0
# 90              3.0              0.0            3.0            0.0
# 91              3.0              0.0            3.0            0.0
# 92              3.0              0.0            3.0            0.0
# 93              3.0              0.0            3.0            0.0
# 94              3.0              0.0            3.0            0.0
# 95              3.0              0.0            3.0            0.0
# 96              3.0              0.0            3.0            0.0
# 97              3.0              0.0            3.0            0.0
# 98              3.0              0.0            3.0            0.0
# 99              3.0              0.0            3.0            0.0
#
#    if_fielding_alignment of_fielding_alignment
# 0               Standard              Standard
# 1               Standard              Standard
# 2               Standard              Standard
# 3               Standard              Standard
# 4               Standard              Standard
# 5               Standard              Standard
# 6               Standard              Standard
# 7               Standard              Standard
# 8               Standard              Standard
# 9               Standard              Standard
# 10              Standard              Standard
# 11             Strategic              Standard
# 12             Strategic              Standard
# 13             Strategic              Standard
# 14             Strategic              Standard
# 15              Standard              Standard
# 16              Standard              Standard
# 17              Standard              Standard
# 18              Standard              Standard
# 19              Standard              Standard
# 20              Standard              Standard
# 21              Standard              Standard
# 22              Standard              Standard
# 23              Standard              Standard
# 24              Standard              Standard
# 25              Standard              Standard
# 26              Standard              Standard
# 27              Standard              Standard
# 28              Standard              Standard
# 29              Standard              Standard
# ..                   ...                   ...
# 70         Infield shift              Standard
# 71         Infield shift              Standard
# 72         Infield shift              Standard
# 73         Infield shift              Standard
# 74              Standard              Standard
# 75              Standard              Standard
# 76              Standard              Standard
# 77              Standard              Standard
# 78              Standard              Standard
# 79              Standard              Standard
# 80              Standard              Standard
# 81              Standard              Standard
# 82              Standard              Standard
# 83              Standard              Standard
# 84              Standard              Standard
# 85              Standard              Standard
# 86              Standard              Standard
# 87              Standard              Standard
# 88              Standard              Standard
# 89              Standard              Standard
# 90         Infield shift              Standard
# 91         Infield shift              Standard
# 92         Infield shift              Standard
# 93         Infield shift              Standard
# 94              Standard              Standard
# 95              Standard              Standard
# 96              Standard              Standard
# 97              Standard              Standard
# 98              Standard              Standard
# 99              Standard              Standard
#
# [100 rows x 90 columns]

# %%
from pybaseball import statcast
data = statcast(start_dt='2014-03-03', end_dt='2018-11-30')
data.head(2)
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# Query unsuccessful for data from 2015-03-15 to 2015-03-20. Skipping these dates.
# Query unsuccessful for data from 2015-03-21 to 2015-03-21. Skipping these dates.
# Query unsuccessful for data from 2015-03-22 to 2015-03-26. Skipping these dates.
# Query unsuccessful for data from 2015-03-27 to 2015-03-27. Skipping these dates.
# Query unsuccessful for data from 2015-03-28 to 2015-04-01. Skipping these dates.
# Query unsuccessful for data from 2015-04-02 to 2015-04-02. Skipping these dates.
# Completed sub-query from 2015-04-03 to 2015-04-08
# Completed sub-query from 2015-04-09 to 2015-04-14
# Completed sub-query from 2015-04-15 to 2015-04-20
# Completed sub-query from 2015-04-21 to 2015-04-26
# Completed sub-query from 2015-04-27 to 2015-05-02
# Completed sub-query from 2015-05-03 to 2015-05-08
# Completed sub-query from 2015-05-09 to 2015-05-14
# Completed sub-query from 2015-05-15 to 2015-05-20
# ...

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-304fa4ce4ebd> in <module>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

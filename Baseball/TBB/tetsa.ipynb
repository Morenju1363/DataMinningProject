# %%
import pandas as pd
df = pd.read_csv('master.csv',  encoding='latin-1')
df.head(40)
# Out:
#     mlb_id            mlb_name mlb_pos mlb_team          mlb_team_long bats  \
# 0   592091         A.J. Achter       P      LAA     Los Angeles Angels    R
# 1   595918           A.J. Cole       P      CLE      Cleveland Indians    R
# 2   454560          A.J. Ellis       C       SD       San Diego Padres    R
# 3   456167        A.J. Griffin       P      TEX          Texas Rangers    R
# 4   543362        A.J. Jimenez       C      TEX          Texas Rangers    R
# 5   621345         A.J. Minter       P      ATL         Atlanta Braves    L
# 6   571963         A.J. Morris       P      CIN        Cincinnati Reds    R
# 7   572041        A.J. Pollock      CF      LAD    Los Angeles Dodgers    R
# 8   519263        A.J. Schugel       P      PIT     Pittsburgh Pirates    R
# 9   571437       Aaron Altherr      CF      PHI  Philadelphia Phillies    R
# 10  502578       Aaron Barrett       P      WSH   Washington Nationals    R
# ...
